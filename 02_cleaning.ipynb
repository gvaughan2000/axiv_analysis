# %%
# Module Imports
import dask.dataframe as dd
from dask.distributed import Client, LocalCluster
import matplotlib.pyplot as plt
import seaborn as sns
from util import clean_journal_ref

# %%
cluster = LocalCluster() 
cluster.scale(8) 

# Sets the number of workers 
cluster.adapt(minimum=1, maximum=8) 

# Allows the cluster to auto scale to 10 when tasks are computed 
client = Client(cluster)
# Out:
# C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 55990 instead
#   warnings.warn(

# %%
defined_dtypes = {'id': str, 'title': str, 'comments':  str, 'journal-ref':  str, 'journal-ref_cleaned':  str,
                  'categories':  str, 'categories_original':str, "journal-ref_original":str,
                  'feild':str, 'category':str, 'sub_category':str, 'first_category':str}

df = dd.read_csv('without_covid.csv', blocksize="256 MiB", dtype=defined_dtypes)
df.head(5)
# Out:
# 2023-05-18 13:08:04,536 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x0000020601094790>, <Task finished name='Task-1976289' coro=<BaseTCPListener._handle_stream() done, defined at C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\tcp.py:605> exception=ValueError('invalid operation on non-started TCPListener')>)
# Traceback (most recent call last):
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\tornado\ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\tornado\tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\tcp.py", line 611, in _handle_stream
#     logger.debug("Incoming connection from %r to %r", address, self.contact_address)
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\tcp.py", line 647, in contact_address
#     host, port = self.get_host_port()
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\tcp.py", line 628, in get_host_port
#     self._check_started()
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\tcp.py", line 603, in _check_started
#     raise ValueError("invalid operation on non-started TCPListener")
# ValueError: invalid operation on non-started TCPListener
# 2023-05-18 13:08:07,715 - distributed.nanny - WARNING - Worker process still alive after 3.1999981689453127 seconds, killing
# 2023-05-18 13:08:07,716 - distributed.nanny - WARNING - Worker process still alive after 3.1999986267089846 seconds, killing
# 2023-05-18 13:08:07,719 - distributed.nanny - WARNING - Worker process still alive after 3.1999983215332035 seconds, killing
# 2023-05-18 13:08:07,720 - distributed.nanny - WARNING - Worker process still alive after 3.199998474121094 seconds, killing
# 2023-05-18 13:08:07,721 - distributed.nanny - WARNING - Worker process still alive after 3.1999987792968754 seconds, killing
# 2023-05-18 13:08:07,722 - distributed.nanny - WARNING - Worker process still alive after 3.1999987792968754 seconds, killing
# 2023-05-18 13:08:07,723 - distributed.nanny - WARNING - Worker process still alive after 3.1999989318847657 seconds, killing
#           id                                              title
# 0  0704.0001  Calculation of prompt diphoton production cros...  \
# 1  0704.0002           Sparsity-certifying Graph Decompositions
# 2  0704.0003  The evolution of the Earth-Moon system based o...
# 3  0704.0004  A determinant of Stirling cycle numbers counts...
# 4  0704.0006  Bosonic characters of atomic Cooper pairs acro...
#
#                                   comments               journal-ref
# 0  37 pages, 15 figures; published version  Phys.Rev.D76:013009,2007  \
# 1    To appear in Graphs and Combinatorics                       NaN
# 2                      23 pages, 3 figures                       NaN
# 3                                 11 pages                       NaN
# 4      6 pages, 4 figures, accepted by PRA                       NaN
#
#           categories
# 0             hep-ph
# 1      math.CO cs.CG
# 2     physics.gen-ph
# 3            math.CO
# 4  cond-mat.mes-hall

# %%
for col in df.columns:
    # make all text entries lower case
    df[col] = df[col].str.lower()
    
    # remove new line characters
    df[col] = df[col].str.replace('\n', '')
    
    # strip leading and trailing spaces
    df[col] = df[col].str.strip()

# %%
df.head(5)
# Out:
#           id                                              title
# 0  0704.0001  calculation of prompt diphoton production cros...  \
# 1  0704.0002           sparsity-certifying graph decompositions
# 2  0704.0003  the evolution of the earth-moon system based o...
# 3  0704.0004  a determinant of stirling cycle numbers counts...
# 4  0704.0006  bosonic characters of atomic cooper pairs acro...
#
#                                   comments               journal-ref
# 0  37 pages, 15 figures; published version  phys.rev.d76:013009,2007  \
# 1    to appear in graphs and combinatorics                       NaN
# 2                      23 pages, 3 figures                       NaN
# 3                                 11 pages                       NaN
# 4      6 pages, 4 figures, accepted by pra                       NaN
#
#           categories
# 0             hep-ph
# 1      math.co cs.cg
# 2     physics.gen-ph
# 3            math.co
# 4  cond-mat.mes-hall

# %%
df['journal-ref_cleaned'] = df['journal-ref'].apply(clean_journal_ref, meta=('journal-ref', str))

# %%
# Removing rows where comments are logged as NaN
df = df.dropna(subset=['comments'])  
# Removing rows where comments are logged as None
df = df[df['comments']!='None']

# %%
# Select only the first category mentioned
df['first_category'] = df['categories'].str.split(' ').str[0]
print(type(df['first_category'][0]))
df.head(5)
# Out:
# <class 'dask.dataframe.core.Series'>
#           id                                              title
# 0  0704.0001  calculation of prompt diphoton production cros...  \
# 1  0704.0002           sparsity-certifying graph decompositions
# 2  0704.0003  the evolution of the earth-moon system based o...
# 3  0704.0004  a determinant of stirling cycle numbers counts...
# 4  0704.0006  bosonic characters of atomic cooper pairs acro...
#
#                                   comments               journal-ref
# 0  37 pages, 15 figures; published version  phys.rev.d76:013009,2007  \
# 1    to appear in graphs and combinatorics                       NaN
# 2                      23 pages, 3 figures                       NaN
# 3                                 11 pages                       NaN
# 4      6 pages, 4 figures, accepted by pra                       NaN
#
#           categories journal-ref_cleaned     first_category
# 0             hep-ph      physics.review             hep-ph
# 1      math.co cs.cg                 NaN            math.co
# 2     physics.gen-ph                 NaN     physics.gen-ph
# 3            math.co                 NaN            math.co
# 4  cond-mat.mes-hall                 NaN  cond-mat.mes-hall

# %%
df[['category', 'sub_category']] = df['categories'].str.split(".", expand=True, n=2)

df['sub_category'] = df['sub_category'].str.split(' ').str[0]
df.head(5)
# Out:
#           id                                              title
# 0  0704.0001  calculation of prompt diphoton production cros...  \
# 1  0704.0002           sparsity-certifying graph decompositions
# 2  0704.0003  the evolution of the earth-moon system based o...
# 3  0704.0004  a determinant of stirling cycle numbers counts...
# 4  0704.0006  bosonic characters of atomic cooper pairs acro...
#
#                                   comments               journal-ref
# 0  37 pages, 15 figures; published version  phys.rev.d76:013009,2007  \
# 1    to appear in graphs and combinatorics                       NaN
# 2                      23 pages, 3 figures                       NaN
# 3                                 11 pages                       NaN
# 4      6 pages, 4 figures, accepted by pra                       NaN
#
#           categories journal-ref_cleaned     first_category  category
# 0             hep-ph      physics.review             hep-ph    hep-ph  \
# 1      math.co cs.cg                 NaN            math.co      math
# 2     physics.gen-ph                 NaN     physics.gen-ph   physics
# 3            math.co                 NaN            math.co      math
# 4  cond-mat.mes-hall                 NaN  cond-mat.mes-hall  cond-mat
#
#   sub_category
# 0         None
# 1           co
# 2       gen-ph
# 3           co
# 4     mes-hall

# %%
df.head(15)
# Out:
#            id                                              title
# 0   0704.0001  calculation of prompt diphoton production cros...  \
# 1   0704.0002           sparsity-certifying graph decompositions
# 2   0704.0003  the evolution of the earth-moon system based o...
# 3   0704.0004  a determinant of stirling cycle numbers counts...
# 4   0704.0006  bosonic characters of atomic cooper pairs acro...
# 5   0704.0007  polymer quantum mechanics and its continuum limit
# 6   0704.0008  numerical solution of shock and ramp compressi...
# 7   0704.0010  partial cubes: structures, characterizations, ...
# 8   0704.0011  computing genus 2 hilbert-siegel modular forms...
# 9   0704.0014             iterated integral and the loop product
# 10  0704.0015  fermionic superstring loop amplitudes in the p...
# 11  0704.0016                 lifetime of doubly charmed baryons
# 12  0704.0017  spectroscopic observations of the intermediate...
# 13  0704.0018    in quest of a generalized callias index theorem
# 14  0704.0019  approximation for extinction probability of th...
#
#                                              comments
# 0             37 pages, 15 figures; published version  \
# 1               to appear in graphs and combinatorics
# 2                                 23 pages, 3 figures
# 3                                            11 pages
# 4                 6 pages, 4 figures, accepted by pra
# 5   16 pages, no figures. typos corrected to match...
# 6                                   minor corrections
# 7                                36 pages, 17 figures
# 8   14 pages; title changed; to appear in experime...
# 9                                  18 pages, 1 figure
# 10  22 pages; signs and coefficients adjusted for ...
# 11                    17 pages, 3 figures and 1 table
# 12  10 pages, 11 figures (figures 3, 4, 7 and 8 at...
# 13  20 pages, v2: an overall sign and typos corrected
# 14                         6 pages, journal-ref added
#
#                                           journal-ref         categories
# 0                            phys.rev.d76:013009,2007             hep-ph  \
# 1                                                 NaN      math.co cs.cg
# 2                                                 NaN     physics.gen-ph
# 3                                                 NaN            math.co
# 4                                                 NaN  cond-mat.mes-hall
# 5                            phys.rev.d76:044016,2007              gr-qc
# 6   journal of applied physics, vol 104, 073536 (2...  cond-mat.mtrl-sci
# 7                                                 NaN            math.co
# 8                                                 NaN    math.nt math.ag
# 9                                                 NaN    math.ca math.at
# 10                                 jhep 0705:034,2007             hep-th
# 11                 commun.theor.phys.49:993-1000,2008             hep-ph
# 12            mon.not.roy.astron.soc.378:211-220,2007           astro-ph
# 13                                                NaN             hep-th
# 14           rims kokyuroku, no.1551, pp.57-62 (2007)    math.pr math.ag
#
#            journal-ref_cleaned     first_category  category sub_category
# 0               physics.review             hep-ph    hep-ph         None
# 1                          NaN            math.co      math           co
# 2                          NaN     physics.gen-ph   physics       gen-ph
# 3                          NaN            math.co      math           co
# 4                          NaN  cond-mat.mes-hall  cond-mat     mes-hall
# 5               physics.review              gr-qc     gr-qc         None
# 6   journal.of.applied.physics  cond-mat.mtrl-sci  cond-mat     mtrl-sci
# 7                          NaN            math.co      math           co
# 8                          NaN            math.nt      math           nt
# 9                          NaN            math.ca      math           ca
# 10                        jhep             hep-th    hep-th         None
# 11        commun.theor.physics             hep-ph    hep-ph         None
# 12      mon.not.roy.astron.soc           astro-ph  astro-ph         None
# 13                         NaN             hep-th    hep-th         None
# 14              rims.kokyuroku            math.pr      math           pr

# %%
field_dict = {'astro-ph':'physics',
             'cond-mat':'physics',
             'gr-qc':'physics',
             'hep-ex':'physics',
             'hep-lat':'physics',
             'hep-ph':'physics',
             'hep-th':'physics',
             'math-ph':'physics',
             'nlin':'physics',
             'nucl-ex':'physics',
             'nucl-th':'physics',
             'physics':'physics',
             'quant-ph':'physics',
              'math':'math',
              'CoRR':'computer science',
              'q-bio':'quantative biology',
              'q-fin':'quantative finance',
              'stat':'statistics',
              'eess':'electrical engineering and systems science',
              'econ':'economics'}

df['feild'] = df['category'].map(field_dict)

# %%
df = df.rename(columns={"categories": "categories_original", "journal-ref": "journal-ref_original"})

# %%
final_df = df.compute()

# %%
final_df.head(5)
# Out:
#           id                                              title
# 0  0704.0001  calculation of prompt diphoton production cros...  \
# 1  0704.0002           sparsity-certifying graph decompositions
# 2  0704.0003  the evolution of the earth-moon system based o...
# 3  0704.0004  a determinant of stirling cycle numbers counts...
# 4  0704.0006  bosonic characters of atomic cooper pairs acro...
#
#                                   comments      journal-ref_original
# 0  37 pages, 15 figures; published version  phys.rev.d76:013009,2007  \
# 1    to appear in graphs and combinatorics                       NaN
# 2                      23 pages, 3 figures                       NaN
# 3                                 11 pages                       NaN
# 4      6 pages, 4 figures, accepted by pra                       NaN
#
#   categories_original journal-ref_cleaned     first_category  category
# 0              hep-ph      physics.review             hep-ph    hep-ph  \
# 1       math.co cs.cg                 NaN            math.co      math
# 2      physics.gen-ph                 NaN     physics.gen-ph   physics
# 3             math.co                 NaN            math.co      math
# 4   cond-mat.mes-hall                 NaN  cond-mat.mes-hall  cond-mat
#
#   sub_category    feild
# 0         None  physics
# 1           co     math
# 2       gen-ph  physics
# 3           co     math
# 4     mes-hall  physics

# %%
final_df.to_csv("without_covid_cleaned.csv", index=False)

# %%
cluster.close()

# %%
def clean_journal_ref(journal):
    # Select only strings to this cleaning is not applied to Nan values
    if type(journal) == str:
        # Errtum shows changes and is usually followed by the journal name 
        # again and a corrected page number or edition number
        # Split string on 'erratum' and remove second half
        journal = journal.split("erratum")[0]

        # make all strings start and end with a dot (.0)
        journal = '.' + journal + '.'

        # replace any spacial character or space with a .
        journal = re.sub('[\W_]', '.', journal)

        # Remove numbers
        journal = re.sub('\d+', '.', journal)

        words_to_replace = ['pp', 'no', 'volume', 'vol', 'issue', 'pages',]
        # Remove month names
        month_names = list(month_name[1:])
        month_names_short = [x[3:] for x in month_names]

        words_to_replace += month_names
        words_to_replace += month_names_short


        for mini_word in words_to_replace:
            journal = journal.replace('.'+mini_word+'.', '.')

        # replace common abbreviations
        for key, value in {'.j.': '.journal.of.', '.rev.': '.review.',
                           '.phys.': '.physics.', '.physical.': '.physics.'}.items():
            journal = journal.replace(key, value)

        # Remove single letters
        journal = re.sub('[.][a-zA-Z](?:[.]|$)', '.', journal)

        # remove repeated dots
        journal = re.sub('\.{2,}', '.', journal)

        # strip dots at the start and end
        journal = journal.strip('.')

    return journal
# Out:
# 2023-05-18 21:34:39,415 - distributed.scheduler - WARNING - Worker failed to heartbeat within 300 seconds. Closing: <WorkerState 'tcp://127.0.0.1:63556', name: 0, status: running, memory: 0, processing: 0>
# 2023-05-18 21:34:39,442 - distributed.scheduler - WARNING - Worker failed to heartbeat within 300 seconds. Closing: <WorkerState 'tcp://127.0.0.1:51853', name: 3, status: running, memory: 0, processing: 0>
# 2023-05-18 21:34:39,477 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:63556'.
# 2023-05-18 21:34:39,556 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:51853'.
# Traceback (most recent call last):
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\multiprocessing\queues.py", line 247, in _feed
#     send_bytes(obj)
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\multiprocessing\connection.py", line 205, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\multiprocessing\connection.py", line 285, in _send_bytes
#     ov, err = _winapi.WriteFile(self._handle, buf, overlapped=True)
# BrokenPipeError: [WinError 232] The pipe is being closed
# 2023-05-19 05:35:58,104 - distributed.scheduler - WARNING - Worker failed to heartbeat within 300 seconds. Closing: <WorkerState 'tcp://127.0.0.1:52964', name: 0, status: running, memory: 0, processing: 0>
# 2023-05-19 05:35:58,241 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:52964'.
# 2023-05-19 05:35:58,247 - distributed.nanny - WARNING - Worker process still alive after 3.1999978637695317 seconds, killing
# 2023-05-19 05:37:20,808 - distributed.nanny - WARNING - Worker process still alive after 3.1999975585937506 seconds, killing
# 2023-05-19 05:37:21,335 - distributed.nanny - ERROR - Error in Nanny killing Worker subprocess
# Traceback (most recent call last):
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\asyncio\tasks.py", line 452, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\nanny.py", line 607, in close
#     await self.kill(timeout=timeout, reason=reason)
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\nanny.py", line 390, in kill
#     await self.process.kill(reason=reason, timeout=0.8 * (deadline - time()))
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\nanny.py", line 844, in kill
#     await process.join(max(0, deadline - time()))
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\process.py", line 330, in join
#     await wait_for(asyncio.shield(self._exit_future), timeout)
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\utils.py", line 1850, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\asyncio\tasks.py", line 454, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
# Task exception was never retrieved
# future: <Task finished name='Task-11669746' coro=<_wrap_awaitable() done, defined at C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\deploy\spec.py:118> exception=RuntimeError('Nanny failed to start.')>
# Traceback (most recent call last):
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\tcp.py", line 498, in connect
#     stream = await self.client.connect(
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\tornado\tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\asyncio\tasks.py", line 490, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\core.py", line 292, in connect
#     comm = await wait_for(
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\utils.py", line 1850, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\asyncio\tasks.py", line 492, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\utils.py", line 1850, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\asyncio\tasks.py", line 442, in wait_for
#     return await fut
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\nanny.py", line 363, in start_unsafe
#     msg = await self.scheduler.register_nanny()
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\core.py", line 1265, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\core.py", line 1509, in connect
#     return await connect_attempt
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\core.py", line 1430, in _connect
#     comm = await connect(
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\core.py", line 318, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:51834 after 30 s
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\deploy\spec.py", line 119, in _wrap_awaitable
#     return await aw
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\core.py", line 545, in start
#     raise RuntimeError(f"{type(self).__name__} failed to start.") from exc
# RuntimeError: Nanny failed to start.
# 2023-05-19 05:37:21,580 - distributed.deploy.adaptive_core - ERROR - Adaptive stopping due to error
# Traceback (most recent call last):
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\tcp.py", line 498, in connect
#     stream = await self.client.connect(
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\tornado\tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\asyncio\tasks.py", line 490, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\core.py", line 292, in connect
#     comm = await wait_for(
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\utils.py", line 1850, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\asyncio\tasks.py", line 492, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\deploy\adaptive_core.py", line 229, in adapt
#     recommendations = await self.recommendations(target)
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\deploy\adaptive.py", line 159, in recommendations
#     await self.cluster
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\deploy\spec.py", line 413, in _
#     await self._correct_state()
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\deploy\spec.py", line 382, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\core.py", line 526, in start
#     raise self.__startup_exc
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\core.py", line 537, in start
#     await wait_for(self.start_unsafe(), timeout=timeout)
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\utils.py", line 1850, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\asyncio\tasks.py", line 442, in wait_for
#     return await fut
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\nanny.py", line 363, in start_unsafe
#     msg = await self.scheduler.register_nanny()
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\core.py", line 1265, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\core.py", line 1509, in connect
#     return await connect_attempt
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\core.py", line 1430, in _connect
#     comm = await connect(
#   File "C:\Users\gv9\AppData\Local\pypoetry\Cache\virtualenvs\portfolio-oVyD_NMl-py3.9\lib\site-packages\distributed\comm\core.py", line 318, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:51834 after 30 s
# 2023-05-19 09:34:41,627 - distributed.scheduler - WARNING - Worker failed to heartbeat within 300 seconds. Closing: <WorkerState 'tcp://127.0.0.1:62734', name: 1, status: running, memory: 0, processing: 0>
# 2023-05-19 09:34:41,645 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:62734'.
# Traceback (most recent call last):
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\multiprocessing\queues.py", line 247, in _feed
#     send_bytes(obj)
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\multiprocessing\connection.py", line 205, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "C:\Users\gv9\.pyenv\pyenv-win\versions\3.9.10\lib\multiprocessing\connection.py", line 285, in _send_bytes
#     ov, err = _winapi.WriteFile(self._handle, buf, overlapped=True)
# BrokenPipeError: [WinError 232] The pipe is being closed
# 2023-05-19 09:35:06,334 - distributed.nanny - WARNING - Worker process still alive after 3.19999740600586 seconds, killing
